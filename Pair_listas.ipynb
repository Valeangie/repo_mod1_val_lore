# %% [markdown]
# EJERCICIOS PAIR

# %%
#1 Duplicar elementos de una lista
lista = [2, 4, 6, 8]

# %%
lista_duplicada = [lista + lista]
print (lista_duplicada)
# Out:
# [[2, 4, 6, 8, 2, 4, 6, 8]]

# %%
#Combinar dos listas
lista1 = [1,2,3]
lista2 = [4,5,6]

# %%
lista_combinada = lista1 + lista2

# %%
print (lista_combinada)
print (lista1 + lista2)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6]

# %%
#Calcular la suma de una lista de números
suma = sum(lista) 
print (suma)
# Out:
# 20

# %%
#Encontrar el valor máximo en una lista
max(lista)
# Out:
# 8

# %%
#Calcular la longitud de una lista
longitud = len(lista)
print(longitud)
# Out:
# 4

# %%
#*******Encontrar el índice de un elemento en una lista
valor_objetivo = 4
indice = lista.index(valor_objetivo)
print (indice)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 #*******Encontrar el índice de un elemento en una lista
#       2 valor_objetivo = 4
# ----> 3 indice = lista.index(valor_objetivo)
#       4 print (indice)
#
# NameError: name 'lista' is not defined

# %%
#7*******Contar ocurrencias de un elemento en una lista
elemento = 8
cantidad = lista_duplicada.count(8)
print (cantidad)
# Out:
# 0

# %%
#Obtener una sublista de una lista
sub_lista = lista_combinada [2:5]
print (sub_lista)
# Out:
# [3, 4, 5]

# %%
#9 Obtener el último elemento de una lista
ultimo = lista[-1]
print (ultimo)
# Out:
# 8

# %%
#10 DUPLICADA

# %%
#Obtener una sublista de una lista
sub_lista2 = lista [1:3]
print (sub_lista2)
# Out:
# [4, 6]

# %%
#12 Reemplazar un elemento en una lista
lista [1]= 5
print (lista)
# Out:
# [2, 5, 6, 8]

# %%
#13 Obtener una lista inversa
lista_inversa = lista[::-1]
print (lista_inversa)
# Out:
# [2, 5, 6, 8]

# %%
#14 Ordenar una lista en orden ascendente
lista_ascendente = sorted(lista)
print(lista_ascendente)
# Out:
# [2, 5, 6, 8]
